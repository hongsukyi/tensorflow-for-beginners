# %%
import tensorflow as tf
import numpy as np
xy= np.loadtxt('./data_xor.txt', unpack=True, dtype='float32')
x_data = xy[0:-1]
y_data = xy[-1]
x_data = np.transpose(xy[0:-1])
y_data = np.reshape(xy[-1:], (4, 1))

print (x_data,y_data)
# Out:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]] [[0.]
#  [1.]
#  [1.]
#  [0.]]

# %%
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

W1 = tf.Variable(tf.random_uniform([2, 2], -1.0, 1.0))
W2 = tf.Variable(tf.random_uniform([2, 1], -1.0, 1.0))

b1 = tf.Variable(tf.zeros([2]), name="Bias1")
b2 = tf.Variable(tf.zeros([1]), name="Bias2")

L2 = tf.sigmoid(tf.matmul(X,W1)+b1)
hypo = tf.sigmoid(tf.matmul(L2,W2) +b2)
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
cost = -tf.reduce_mean(Y * tf.log(hypo) + (1 - Y) * tf.log(1 - hypo))

# %%
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

learning_rate = 0.1
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
train = optimizer.minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
for step in range(50000):
    feed = {X: x_data, Y: y_data}
    sess.run(train, feed_dict=feed)
    if step % 1000 == 0:            
        print (step, sess.run(cost, feed_dict=feed), sess.run(W1), sess.run(W2))
# Out:
# 0 0.7339466 [[ 0.67559046 -0.35130152]
#  [ 0.48656273  0.4851958 ]] [[-0.5382359 ]
#  [-0.45553344]]
# 1000 0.69330466 [[ 0.5652882  -0.34624422]
#  [ 0.3233839   0.4959647 ]] [[-0.18997061]
#  [-0.30451626]]
# 2000 0.6930833 [[ 0.5321293  -0.3445747 ]
#  [ 0.2596752   0.54230577]] [[-0.1190491 ]
#  [-0.32369727]]
# 3000 0.6928717 [[ 0.51832247 -0.37025896]
#  [ 0.2264775   0.614286  ]] [[-0.06861636]
#  [-0.3577443 ]]
# 4000 0.69241315 [[ 0.5134725  -0.4415685 ]
#  [ 0.21090145  0.73355144]] [[-0.02170594]
#  [-0.42468306]]
# 5000 0.6906487 [[ 0.51368785 -0.6170876 ]
#  [ 0.21404816  0.96874404]] [[ 0.04161115]
#  [-0.57558763]]
# 6000 0.6785922 [[ 0.5115704  -1.1340653 ]
#  [ 0.27385083  1.5645027 ]] [[ 0.18793903]
#  [-1.0115168 ]]
# 7000 0.6063788 [[ 0.41850325 -2.4831152 ]
#  [ 0.71595496  2.984626  ]] [[ 0.6878035]
#  [-2.2364955]]
# 8000 0.49146476 [[-0.01246609 -3.8332822 ]
#  [ 1.9002141   4.5273156 ]] [[ 2.048505 ]
#  [-3.8720329]]
# 9000 0.16575207 [[-3.2081213 -5.0020933]
#  [ 3.0839052  5.4973435]] [[ 5.1609535]
#  [-5.3710494]]
# 10000 0.067707576 [[-4.3967457 -5.616317 ]
#  [ 4.1688547  5.9167295]] [[ 7.091    ]
#  [-6.7096243]]
# 11000 0.041158874 [[-4.9099774 -5.929409 ]
#  [ 4.6633253  6.173242 ]] [[ 8.09364  ]
#  [-7.5503225]]
# 12000 0.029291462 [[-5.2205877 -6.1313457]
#  [ 4.9665737  6.353681 ]] [[ 8.757919]
#  [-8.151301]]
# 13000 0.022638423 [[-5.4384027 -6.2784734]
#  [ 5.1806655  6.491168 ]] [[ 9.252798]
#  [-8.616463]]
# 14000 0.018404555 [[-5.6040845 -6.39342  ]
#  [ 5.344195   6.601442 ]] [[ 9.646644]
#  [-8.994965]]
# 15000 0.015482255 [[-5.7367606 -6.4873424]
#  [ 5.4755106  6.6930785]] [[ 9.973544]
#  [-9.313599]]
# 16000 0.013347964 [[-5.846825  -6.5665174]
#  [ 5.5846577  6.771221 ]] [[10.252879]
#  [-9.5885  ]]
# 17000 0.01172297 [[-5.940517  -6.634799 ]
#  [ 5.6776996  6.839181 ]] [[10.496693]
#  [-9.830096]]
# 18000 0.010445658 [[-6.021848  -6.694728 ]
#  [ 5.758553   6.8991957]] [[ 10.712995]
#  [-10.045502]]
# 19000 0.009415893 [[-6.093546  -6.7480564]
#  [ 5.8298855  6.952859 ]] [[ 10.90734 ]
#  [-10.239798]]
# 20000 0.008568484 [[-6.1575403 -6.796047 ]
#  [ 5.8935966  7.0013304]] [[ 11.083781]
#  [-10.416721]]
# 21000 0.007859248 [[-6.215247 -6.839634]
#  [ 5.95107   7.045492]] [[ 11.245341]
#  [-10.579094]]
# 22000 0.0072571835 [[-6.2677293 -6.879526 ]
#  [ 6.0033603  7.08601  ]] [[ 11.394319]
#  [-10.729114]]
# 23000 0.0067398134 [[-6.3158092 -6.916281 ]
#  [ 6.0512805  7.123419 ]] [[ 11.5325365]
#  [-10.868503 ]]
# 24000 0.0062905196 [[-6.360131  -6.9503403]
#  [ 6.0954576  7.158131 ]] [[ 11.661452]
#  [-10.998676]]
# 25000 0.0058967816 [[-6.4012027 -6.98206  ]
#  [ 6.1364136  7.190513 ]] [[ 11.782229]
#  [-11.120767]]
# 26000 0.005548955 [[-6.439466  -7.011723 ]
#  [ 6.17456    7.2208366]] [[ 11.895843]
#  [-11.235709]]
# 27000 0.00523944 [[-6.4752336 -7.0395784]
#  [ 6.2102394  7.2493234]] [[ 12.003089]
#  [-11.344298]]
# 28000 0.004962375 [[-6.508808  -7.0658255]
#  [ 6.2437186  7.2761993]] [[ 12.104641]
#  [-11.447184]]
# 29000 0.00471285 [[-6.5404377 -7.09062  ]
#  [ 6.275263   7.3016114]] [[ 12.201087]
#  [-11.54494 ]]
# 30000 0.0044869813 [[-6.5702987 -7.1141033]
#  [ 6.3050585  7.3257174]] [[ 12.292888]
#  [-11.638066]]
# 31000 0.004281625 [[-6.5985966 -7.13644  ]
#  [ 6.3332887  7.3486247]] [[ 12.3805065]
#  [-11.726943 ]]
# 32000 0.0040940447 [[-6.6254616 -7.157711 ]
#  [ 6.360083   7.3704615]] [[ 12.464284]
#  [-11.811977]]
# 33000 0.0039220755 [[-6.6510434 -7.1779933]
#  [ 6.3855906  7.391301 ]] [[ 12.5445795]
#  [-11.893471 ]]
# 34000 0.0037638543 [[-6.6754184 -7.197371 ]
#  [ 6.4099145  7.411226 ]] [[ 12.621599]
#  [-11.971712]]
# 35000 0.0036178487 [[-6.6987247 -7.2159424]
#  [ 6.4331684  7.4303308]] [[ 12.695662]
#  [-12.046932]]
# 36000 0.0034825872 [[-6.72103   -7.2337823]
#  [ 6.4554176  7.448669 ]] [[ 12.766989]
#  [-12.119378]]
# 37000 0.0033570789 [[-6.74241   -7.2508874]
#  [ 6.476739   7.466276 ]] [[ 12.835715]
#  [-12.189195]]
# 38000 0.0032401693 [[-6.762951  -7.2673554]
#  [ 6.497217   7.4832225]] [[ 12.902106]
#  [-12.256682]]
# 39000 0.0031311219 [[-6.7827115 -7.2832456]
#  [ 6.516945   7.4995823]] [[ 12.966223]
#  [-12.321836]]
# 40000 0.0030290822 [[-6.8017044 -7.2985797]
#  [ 6.53587    7.5153704]] [[ 13.028286]
#  [-12.384913]]
# 41000 0.00293345 [[-6.82004   -7.3133736]
#  [ 6.5541706  7.5305815]] [[ 13.0884075]
#  [-12.446025 ]]
# 42000 0.0028435965 [[-6.8377585 -7.327671 ]
#  [ 6.5718136  7.545302 ]] [[ 13.146709]
#  [-12.505291]]
# 43000 0.002759086 [[-6.854822  -7.3414993]
#  [ 6.588837   7.559562 ]] [[ 13.20333 ]
#  [-12.562841]]
# 44000 0.0026794542 [[-6.8713427 -7.3548756]
#  [ 6.605317   7.5733905]] [[ 13.258234]
#  [-12.618675]]
# 45000 0.0026042066 [[-6.8873444 -7.367843 ]
#  [ 6.6212754  7.5867467]] [[ 13.311661]
#  [-12.672975]]
# 46000 0.0025330435 [[-6.902851 -7.380441]
#  [ 6.636739  7.599712]] [[ 13.363631]
#  [-12.725844]]
# 47000 0.0024656802 [[-6.9178915 -7.3927135]
#  [ 6.651732   7.6123266]] [[ 13.414261]
#  [-12.777274]]
# 48000 0.0024017724 [[-6.9324946 -7.4046345]
#  [ 6.6662893  7.6246357]] [[ 13.463512]
#  [-12.827382]]
# 49000 0.0023410206 [[-6.946696  -7.4161534]
#  [ 6.680437   7.6365566]] [[ 13.511596]
#  [-12.876304]]

# %%
correct_prediction = tf.equal(tf.floor(hypo + 0.5), Y)

accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

print (sess.run([hypo, tf.floor(hypo + 0.5), correct_prediction], feed_dict=feed))
print ('accuracy:', sess.run(accuracy, feed_dict={X: x_data, Y: y_data}))
# print 'accuracy:', accuracy.eval({X: x_data, Y: y_data})
# Out:
# [array([[0.00219095],
#        [0.9979608 ],
#        [0.9969999 ],
#        [0.00189224]], dtype=float32), array([[0.],
#        [1.],
#        [1.],
#        [0.]], dtype=float32), array([[ True],
#        [ True],
#        [ True],
#        [ True]])]
# accuracy: 1.0
